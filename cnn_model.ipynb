# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Yeast
# Out:
# /content/drive/MyDrive/Yeast

# %%
import os
import cv2
import tensorflow as tf
from keras.layers import Conv2D, BatchNormalization, MaxPooling2D, Flatten, Dense , Dropout
from keras.models import Sequential
from keras.metrics import F1Score, Accuracy
from keras.optimizers import SGD
from sklearn.model_selection import train_test_split, KFold
from keras.utils import to_categorical
from numpy import mean,std
from matplotlib import pyplot as plt
import os
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import shuffle
import numpy as np
from keras.models import load_model
from google.colab.patches import cv2_imshow

# %% [markdown]
# ### *Xây dựng mô hình CNN*

# %%
train_file = os.listdir("dataset/non-aug/train/abnormal")[:600] + os.listdir("dataset/non-aug/train/normal")[:600]

# %%
valid_file = os.listdir("dataset/non-aug/train/abnormal")[600:] + os.listdir("dataset/non-aug/train/normal")[600:]

# %%
print(len(train_file))
print(len(valid_file))
# Out:
# 1200
# 202

# %%
def pad_image(image_path, target_size):
    # Đọc ảnh từ đường dẫn
    img = cv2.imread(image_path)

    # Kiểm tra nếu ảnh được đọc thành công
    if img is None:
        raise ValueError(f"Could not read image from {image_path}")

    # Lấy kích thước hiện tại của ảnh
    h, w = img.shape[:2]

    # Tính toán số lượng padding cần thiết
    pad_h = max(0, (target_size[0] - h) // 2)
    pad_w = max(0, (target_size[1] - w) // 2)

    ex1 = (target_size[0] - h) % 2
    ex2 = (target_size[1] - w) % 2
    # Pad ảnh sao cho kích thước đạt target_size
    padded_img = cv2.copyMakeBorder(
        img,
        pad_h, pad_h + ex1, pad_w, pad_w +ex2,
        borderType=cv2.BORDER_CONSTANT,
        value=0  # Padding với màu đen (giá trị 0)
    )

    # Cắt ảnh nếu kích thước vượt quá target_size sau padding
    padded_img = padded_img[:target_size[0], :target_size[1]]

    return padded_img

# %%
x_train = []
y_train = []
for i in range(len(train_file)):
  if(i < len(train_file)//2):
    img = cv2.imread("dataset/non-aug/train/abnormal/"+train_file[i])
    img = pad_image("dataset/non-aug/train/abnormal/"+train_file[i], (32,32))
    x_train.append(img)
    y_train.append(1)
  else:
    img = cv2.imread("dataset/non-aug/train/normal/"+train_file[i])
    img = pad_image("dataset/non-aug/train/normal/"+train_file[i], (32,32))
    x_train.append(img)
    y_train.append(0)

# %%
x_valid = []
y_valid = []
for i in range(len(valid_file)):
  if(i < len(os.listdir("dataset/non-aug/train/abnormal")) - len(train_file)//2):
    img = cv2.imread("dataset/non-aug/train/abnormal/"+valid_file[i])
    img = pad_image("dataset/non-aug/train/abnormal/"+valid_file[i], (32,32))
    x_valid.append(img)
    y_valid.append(1)
  else:
    img = cv2.imread("dataset/non-aug/train/normal/"+valid_file[i])
    img = pad_image("dataset/non-aug/train/normal/"+valid_file[i], (32,32))
    x_valid.append(img)
    y_valid.append(0)

# %%
x_train,y_train = shuffle(x_train,y_train, random_state = 19)
x_valid,y_valid = shuffle(x_valid,y_valid,  random_state = 4)

# %%
def prep_pixels(train, test):
 # convert from integers to floats
 train_norm = train.astype('float32')
 test_norm = test.astype('float32')
 # normalize to range 0-1
 train_norm = train_norm / 255.0
 test_norm = test_norm / 255.0
 # return normalized images
 return train_norm, test_norm

# %%
x_train = np.array(x_train)
x_valid = np.array(x_valid)
x_train, x_valid = prep_pixels(x_train, x_valid)
y_train = np.array(y_train)
y_valid = np.array(y_valid)

# %%
save_dir = 'files/non-aug'
filepath = os.path.join(save_dir, 'best_yeast_classification_model.hdf5')

# %%
callback_1 = ModelCheckpoint(
    filepath,
    monitor='val_accuracy',
    save_best_only=True,
    save_weights_only=False,
    save_freq='epoch',
    mode='max',
    verbose=1 # Hiển thị thông tin model lúc checkpoint
)
def define_model():
    model = Sequential()

    # Layer Conv2D đầu tiên
    model.add(Conv2D(32, (3, 3), activation="relu", input_shape=(32, 32, 3), padding="same"))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # Layer Conv2D thứ hai
    model.add(Conv2D(64, (3, 3), activation="relu", padding="same"))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))

    # Layer Conv2D thứ ba
    model.add(Conv2D(128, (3, 3), activation="relu", padding="same"))
    model.add(BatchNormalization())
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.3))
    # Flatten và Dense
    model.add(Flatten())
    model.add(Dense(64, activation="relu"))
    model.add(Dense(2, activation="softmax"))


    model.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

    return model

# Định nghĩa mô hình
model = define_model()

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_36 (Conv2D)          (None, 32, 32, 32)        896
#
#  batch_normalization_36 (Ba  (None, 32, 32, 32)        128
#  tchNormalization)
#
#  max_pooling2d_36 (MaxPooli  (None, 16, 16, 32)        0
#  ng2D)
#
#  conv2d_37 (Conv2D)          (None, 16, 16, 64)        18496
#
#  batch_normalization_37 (Ba  (None, 16, 16, 64)        256
#  tchNormalization)
#
#  max_pooling2d_37 (MaxPooli  (None, 8, 8, 64)          0
#  ng2D)
#
#  conv2d_38 (Conv2D)          (None, 8, 8, 128)         73856
#
#  batch_normalization_38 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  max_pooling2d_38 (MaxPooli  (None, 4, 4, 128)         0
#  ng2D)
#
#  dropout_5 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten_12 (Flatten)        (None, 2048)              0
#
#  dense_36 (Dense)            (None, 64)                131136
#
#  dense_37 (Dense)            (None, 2)                 130
#
# =================================================================
# Total params: 225410 (880.51 KB)
# Trainable params: 224962 (878.76 KB)
# Non-trainable params: 448 (1.75 KB)
# _________________________________________________________________

# %%
model.fit(x_train,y_train, epochs=50, batch_size=16, validation_data=(x_valid, y_valid), callbacks=[callback_1])
# Out:
# Epoch 1/50
# 75/75 [==============================] - ETA: 0s - loss: 0.9123 - accuracy: 0.5125
# Epoch 1: val_accuracy improved from -inf to 0.50495, saving model to files/non-aug/best_yeast_classification_model.hdf5
# 75/75 [==============================] - 6s 58ms/step - loss: 0.9123 - accuracy: 0.5125 - val_loss: 0.8239 - val_accuracy: 0.5050
# Epoch 2/50
# 75/75 [==============================] - ETA: 0s - loss: 0.6879 - accuracy: 0.5442
# Epoch 2: val_accuracy did not improve from 0.50495
# 75/75 [==============================] - 4s 51ms/step - loss: 0.6879 - accuracy: 0.5442 - val_loss: 0.8423 - val_accuracy: 0.5050
# Epoch 3/50
# 75/75 [==============================] - ETA: 0s - loss: 0.6701 - accuracy: 0.5908
# Epoch 3: val_accuracy improved from 0.50495 to 0.54455, saving model to files/non-aug/best_yeast_classification_model.hdf5
# 75/75 [==============================] - 6s 76ms/step - loss: 0.6701 - accuracy: 0.5908 - val_loss: 0.6845 - val_accuracy: 0.5446
# Epoch 4/50
# 75/75 [==============================] - ETA: 0s - loss: 0.6737 - accuracy: 0.5900
# Epoch 4: val_accuracy improved from 0.54455 to 0.64356, saving model to files/non-aug/best_yeast_classification_model.hdf5
# 75/75 [==============================] - 4s 49ms/step - loss: 0.6737 - accuracy: 0.5900 - val_loss: 0.6736 - val_accuracy: 0.6436
# Epoch 5/50
# 75/75 [==============================] - ETA: 0s - loss: 0.6561 - accuracy: 0.5967
# Epoch 5: val_accuracy did not improve from 0.64356
# 75/75 [==============================] - 3s 45ms/step - loss: 0.6561 - accuracy: 0.5967 - val_loss: 0.7056 - val_accuracy: 0.5149
# Epoch 6/50
# 75/75 [==============================] - ETA: 0s - loss: 0.6436 - accuracy: 0.6358
# Epoch 6: val_accuracy did not improve from 0.64356
# 75/75 [==============================] - 4s 59ms/step - loss: 0.6436 - accuracy: 0.6358 - val_loss: 0.7096 - val_accuracy: 0.4950
# Epoch 7/50
# 75/75 [==============================] - ETA: 0s - loss: 0.6435 - accuracy: 0.6192
# Epoch 7: val_accuracy did not improve from 0.64356
# 75/75 [==============================] - 5s 60ms/step - loss: 0.6435 - accuracy: 0.6192 - val_loss: 0.8357 - val_accuracy: 0.4950
# Epoch 8/50
# 74/75 [============================>.] - ETA: 0s - loss: 0.6288 - accuracy: 0.6385
# Epoch 8: val_accuracy improved from 0.64356 to 0.68812, saving model to files/non-aug/best_yeast_classification_model.hdf5
# 75/75 [==============================] - 4s 51ms/step - loss: 0.6275 - accuracy: 0.6400 - val_loss: 0.5989 - val_accuracy: 0.6881
# Epoch 9/50
# 75/75 [==============================] - ETA: 0s - loss: 0.5582 - accuracy: 0.6983
# Epoch 9: val_accuracy did not improve from 0.68812
# 75/75 [==============================] - 3s 46ms/step - loss: 0.5582 - accuracy: 0.6983 - val_loss: 0.9560 - val_accuracy: 0.5099
# Epoch 10/50
# 75/75 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.7567
# Epoch 10: val_accuracy did not improve from 0.68812
# 75/75 [==============================] - 5s 66ms/step - loss: 0.5000 - accuracy: 0.7567 - val_loss: 1.1902 - val_accuracy: 0.4950
# Epoch 11/50
# 75/75 [==============================] - ETA: 0s - loss: 0.4705 - accuracy: 0.7692
# Epoch 11: val_accuracy improved from 0.68812 to 0.75248, saving model to files/non-aug/best_yeast_classification_model.hdf5
# 75/75 [==============================] - 5s 63ms/step - loss: 0.4705 - accuracy: 0.7692 - val_loss: 0.4740 - val_accuracy: 0.7525
# Epoch 12/50
# 74/75 [============================>.] - ETA: 0s - loss: 0.4807 - accuracy: 0.7669
# Epoch 12: val_accuracy did not improve from 0.75248
# 75/75 [==============================] - 3s 46ms/step - loss: 0.4785 - accuracy: 0.7683 - val_loss: 0.8918 - val_accuracy: 0.5248
# Epoch 13/50
# 75/75 [==============================] - ETA: 0s - loss: 0.4507 - accuracy: 0.7800
# Epoch 13: val_accuracy did not improve from 0.75248
# 75/75 [==============================] - 4s 48ms/step - loss: 0.4507 - accuracy: 0.7800 - val_loss: 0.5223 - val_accuracy: 0.6832
# Epoch 14/50
# 74/75 [============================>.] - ETA: 0s - loss: 0.4059 - accuracy: 0.8100
# Epoch 14: val_accuracy improved from 0.75248 to 0.82178, saving model to files/non-aug/best_yeast_classification_model.hdf5
# 75/75 [==============================] - 6s 78ms/step - loss: 0.4041 - accuracy: 0.8108 - val_loss: 0.4096 - val_accuracy: 0.8218
# Epoch 15/50
# 75/75 [==============================] - ETA: 0s - loss: 0.4179 - accuracy: 0.8033
# Epoch 15: val_accuracy improved from 0.82178 to 0.87129, saving model to files/non-aug/best_yeast_classification_model.hdf5
# 75/75 [==============================] - 3s 45ms/step - loss: 0.4179 - accuracy: 0.8033 - val_loss: 0.3502 - val_accuracy: 0.8713
# Epoch 16/50
# 74/75 [============================>.] - ETA: 0s - loss: 0.3874 - accuracy: 0.8184
# Epoch 16: val_accuracy did not improve from 0.87129
# 75/75 [==============================] - 3s 47ms/step - loss: 0.3886 - accuracy: 0.8183 - val_loss: 0.3600 - val_accuracy: 0.8564
# Epoch 17/50
# 75/75 [==============================] - ETA: 0s - loss: 0.3630 - accuracy: 0.8325
# Epoch 17: val_accuracy did not improve from 0.87129
# 75/75 [==============================] - 4s 53ms/step - loss: 0.3630 - accuracy: 0.8325 - val_loss: 0.9577 - val_accuracy: 0.5495
# Epoch 18/50
# 74/75 [============================>.] - ETA: 0s - loss: 0.3329 - accuracy: 0.8522
# Epoch 18: val_accuracy did not improve from 0.87129
# 75/75 [==============================] - 5s 66ms/step - loss: 0.3336 - accuracy: 0.8525 - val_loss: 0.3664 - val_accuracy: 0.8119
# Epoch 19/50
# 75/75 [==============================] - ETA: 0s - loss: 0.3327 - accuracy: 0.8483
# Epoch 19: val_accuracy improved from 0.87129 to 0.90099, saving model to files/non-aug/best_yeast_classification_model.hdf5
# 75/75 [==============================] - 4s 50ms/step - loss: 0.3327 - accuracy: 0.8483 - val_loss: 0.2809 - val_accuracy: 0.9010
# Epoch 20/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2926 - accuracy: 0.8758
# Epoch 20: val_accuracy improved from 0.90099 to 0.93564, saving model to files/non-aug/best_yeast_classification_model.hdf5
# 75/75 [==============================] - 3s 45ms/step - loss: 0.2926 - accuracy: 0.8758 - val_loss: 0.2666 - val_accuracy: 0.9356
# Epoch 21/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2632 - accuracy: 0.8775
# Epoch 21: val_accuracy did not improve from 0.93564
# 75/75 [==============================] - 5s 62ms/step - loss: 0.2632 - accuracy: 0.8775 - val_loss: 0.3402 - val_accuracy: 0.8267
# Epoch 22/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2991 - accuracy: 0.8700
# Epoch 22: val_accuracy did not improve from 0.93564
# 75/75 [==============================] - 4s 59ms/step - loss: 0.2991 - accuracy: 0.8700 - val_loss: 0.1952 - val_accuracy: 0.9307
# Epoch 23/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2697 - accuracy: 0.8875
# Epoch 23: val_accuracy did not improve from 0.93564
# 75/75 [==============================] - 3s 44ms/step - loss: 0.2697 - accuracy: 0.8875 - val_loss: 0.2172 - val_accuracy: 0.9158
# Epoch 24/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2543 - accuracy: 0.8892
# Epoch 24: val_accuracy did not improve from 0.93564
# 75/75 [==============================] - 3s 45ms/step - loss: 0.2543 - accuracy: 0.8892 - val_loss: 1.8092 - val_accuracy: 0.5198
# Epoch 25/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2722 - accuracy: 0.8750
# Epoch 25: val_accuracy did not improve from 0.93564
# 75/75 [==============================] - 5s 61ms/step - loss: 0.2722 - accuracy: 0.8750 - val_loss: 0.9244 - val_accuracy: 0.6634
# Epoch 26/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2375 - accuracy: 0.8958
# Epoch 26: val_accuracy did not improve from 0.93564
# 75/75 [==============================] - 5s 60ms/step - loss: 0.2375 - accuracy: 0.8958 - val_loss: 0.1847 - val_accuracy: 0.9257
# Epoch 27/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1981 - accuracy: 0.9242
# Epoch 27: val_accuracy did not improve from 0.93564
# 75/75 [==============================] - 4s 47ms/step - loss: 0.1981 - accuracy: 0.9242 - val_loss: 0.5866 - val_accuracy: 0.7525
# Epoch 28/50
# 75/75 [==============================] - ETA: 0s - loss: 0.2242 - accuracy: 0.9033
# Epoch 28: val_accuracy did not improve from 0.93564
# 75/75 [==============================] - 4s 47ms/step - loss: 0.2242 - accuracy: 0.9033 - val_loss: 0.4775 - val_accuracy: 0.8465
# Epoch 29/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1873 - accuracy: 0.9283
# Epoch 29: val_accuracy did not improve from 0.93564
# 75/75 [==============================] - 5s 69ms/step - loss: 0.1873 - accuracy: 0.9283 - val_loss: 0.2107 - val_accuracy: 0.9158
# Epoch 30/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1706 - accuracy: 0.9283
# Epoch 30: val_accuracy did not improve from 0.93564
# 75/75 [==============================] - 4s 51ms/step - loss: 0.1706 - accuracy: 0.9283 - val_loss: 0.1733 - val_accuracy: 0.9257
# Epoch 31/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1551 - accuracy: 0.9400
# Epoch 31: val_accuracy did not improve from 0.93564
# 75/75 [==============================] - 3s 45ms/step - loss: 0.1551 - accuracy: 0.9400 - val_loss: 0.1941 - val_accuracy: 0.9307
# Epoch 32/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1304 - accuracy: 0.9483
# Epoch 32: val_accuracy did not improve from 0.93564
# 75/75 [==============================] - 3s 45ms/step - loss: 0.1304 - accuracy: 0.9483 - val_loss: 0.4006 - val_accuracy: 0.8465
# Epoch 33/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1470 - accuracy: 0.9350
# Epoch 33: val_accuracy did not improve from 0.93564
# 75/75 [==============================] - 6s 75ms/step - loss: 0.1470 - accuracy: 0.9350 - val_loss: 0.1967 - val_accuracy: 0.9208
# Epoch 34/50
# 74/75 [============================>.] - ETA: 0s - loss: 0.1273 - accuracy: 0.9485
# Epoch 34: val_accuracy did not improve from 0.93564
# 75/75 [==============================] - 4s 48ms/step - loss: 0.1293 - accuracy: 0.9483 - val_loss: 0.1988 - val_accuracy: 0.9208
# Epoch 35/50
# 74/75 [============================>.] - ETA: 0s - loss: 0.1213 - accuracy: 0.9476
# Epoch 35: val_accuracy improved from 0.93564 to 0.94059, saving model to files/non-aug/best_yeast_classification_model.hdf5
# 75/75 [==============================] - 4s 51ms/step - loss: 0.1226 - accuracy: 0.9467 - val_loss: 0.1807 - val_accuracy: 0.9406
# Epoch 36/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1324 - accuracy: 0.9433
# Epoch 36: val_accuracy did not improve from 0.94059
# 75/75 [==============================] - 4s 49ms/step - loss: 0.1324 - accuracy: 0.9433 - val_loss: 0.2168 - val_accuracy: 0.9109
# Epoch 37/50
# 74/75 [============================>.] - ETA: 0s - loss: 0.1177 - accuracy: 0.9493
# Epoch 37: val_accuracy did not improve from 0.94059
# 75/75 [==============================] - 5s 71ms/step - loss: 0.1173 - accuracy: 0.9492 - val_loss: 0.1777 - val_accuracy: 0.9356
# Epoch 38/50
# 74/75 [============================>.] - ETA: 0s - loss: 0.1304 - accuracy: 0.9451
# Epoch 38: val_accuracy did not improve from 0.94059
# 75/75 [==============================] - 4s 47ms/step - loss: 0.1304 - accuracy: 0.9450 - val_loss: 0.2264 - val_accuracy: 0.9208
# Epoch 39/50
# 74/75 [============================>.] - ETA: 0s - loss: 0.1327 - accuracy: 0.9451
# Epoch 39: val_accuracy did not improve from 0.94059
# 75/75 [==============================] - 3s 45ms/step - loss: 0.1339 - accuracy: 0.9442 - val_loss: 0.3993 - val_accuracy: 0.8267
# Epoch 40/50
# 75/75 [==============================] - ETA: 0s - loss: 0.1049 - accuracy: 0.9525
# Epoch 40: val_accuracy did not improve from 0.94059
# 75/75 [==============================] - 4s 52ms/step - loss: 0.1049 - accuracy: 0.9525 - val_loss: 0.7580 - val_accuracy: 0.7525
# Epoch 41/50
# 74/75 [============================>.] - ETA: 0s - loss: 0.0823 - accuracy: 0.9704
# Epoch 41: val_accuracy did not improve from 0.94059
# 75/75 [==============================] - 5s 68ms/step - loss: 0.0849 - accuracy: 0.9700 - val_loss: 0.1849 - val_accuracy: 0.9257
# Epoch 42/50
# 74/75 [============================>.] - ETA: 0s - loss: 0.0758 - accuracy: 0.9730
# Epoch 42: val_accuracy did not improve from 0.94059
# 75/75 [==============================] - 4s 47ms/step - loss: 0.0762 - accuracy: 0.9725 - val_loss: 0.1886 - val_accuracy: 0.9208
# Epoch 43/50
# 74/75 [============================>.] - ETA: 0s - loss: 0.0645 - accuracy: 0.9755
# Epoch 43: val_accuracy did not improve from 0.94059
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0649 - accuracy: 0.9750 - val_loss: 0.3044 - val_accuracy: 0.9010
# Epoch 44/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0747 - accuracy: 0.9733
# Epoch 44: val_accuracy did not improve from 0.94059
# 75/75 [==============================] - 4s 55ms/step - loss: 0.0747 - accuracy: 0.9733 - val_loss: 0.2486 - val_accuracy: 0.9109
# Epoch 45/50
# 74/75 [============================>.] - ETA: 0s - loss: 0.0816 - accuracy: 0.9679
# Epoch 45: val_accuracy did not improve from 0.94059
# 75/75 [==============================] - 5s 68ms/step - loss: 0.0819 - accuracy: 0.9675 - val_loss: 0.4250 - val_accuracy: 0.8713
# Epoch 46/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0630 - accuracy: 0.9758
# Epoch 46: val_accuracy did not improve from 0.94059
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0630 - accuracy: 0.9758 - val_loss: 0.2108 - val_accuracy: 0.9257
# Epoch 47/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 0.9633
# Epoch 47: val_accuracy did not improve from 0.94059
# 75/75 [==============================] - 3s 44ms/step - loss: 0.0958 - accuracy: 0.9633 - val_loss: 0.2892 - val_accuracy: 0.8960
# Epoch 48/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0760 - accuracy: 0.9683
# Epoch 48: val_accuracy did not improve from 0.94059
# 75/75 [==============================] - 4s 54ms/step - loss: 0.0760 - accuracy: 0.9683 - val_loss: 0.3780 - val_accuracy: 0.8911
# Epoch 49/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0657 - accuracy: 0.9692
# Epoch 49: val_accuracy did not improve from 0.94059
# 75/75 [==============================] - 5s 68ms/step - loss: 0.0657 - accuracy: 0.9692 - val_loss: 0.5205 - val_accuracy: 0.8465
# Epoch 50/50
# 75/75 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.9758
# Epoch 50: val_accuracy did not improve from 0.94059
# 75/75 [==============================] - 3s 45ms/step - loss: 0.0580 - accuracy: 0.9758 - val_loss: 0.6189 - val_accuracy: 0.8564

# %%
model = tf.keras.models.load_model('files/non-aug/best_yeast_classification_model.hdf5')

# %%
def pad_img(img, target_size):
    # Lấy kích thước hiện tại của ảnh
    h, w = img.shape[:2]

    # Tính toán số lượng padding cần thiết
    pad_h = max(0, (target_size[0] - h) // 2)
    pad_w = max(0, (target_size[1] - w) // 2)

    ex1 = (target_size[0] - h) % 2
    ex2 = (target_size[1] - w) % 2
    # Pad ảnh sao cho kích thước đạt target_size
    padded_img = cv2.copyMakeBorder(
        img,
        pad_h, pad_h + ex1, pad_w, pad_w +ex2,
        borderType=cv2.BORDER_CONSTANT,
        value=0  # Padding với màu đen (giá trị 0)
    )

    # Cắt ảnh nếu kích thước vượt quá target_size sau padding
    padded_img = padded_img[:target_size[0], :target_size[1]]

    return padded_img

# %%
img = pad_img(x_train[0], (32,32))

# %%
plt.imshow(img)
plt.show()

# %%
input_image = np.expand_dims(pad_img(x_train[0], (32,32)), axis=0)

# %%
model.predict(input_image)
# Out:
# 1/1 [==============================] - 0s 447ms/step
# array([[0.00104464, 0.99895537]], dtype=float32)

# %%
labels = {
    0 : "Normal",
    1 : "Abnormal"
}

# %%
for i in range(10):
  img = pad_img(x_train[i], (32,32))
  plt.imshow(img)
  plt.show()
  input_image = np.expand_dims(pad_img(x_train[i], (32,32)), axis=0)
  print(labels[np.argmax(model.predict(input_image))])
# Out:
# 1/1 [==============================] - 0s 92ms/step
# Abnormal
# 1/1 [==============================] - 0s 46ms/step
# Normal
# 1/1 [==============================] - 0s 34ms/step
# Abnormal
# 1/1 [==============================] - 0s 23ms/step
# Normal
# 1/1 [==============================] - 0s 31ms/step
# Abnormal
# 1/1 [==============================] - 0s 22ms/step
# Normal
# 1/1 [==============================] - 0s 22ms/step
# Normal
# 1/1 [==============================] - 0s 26ms/step
# Normal
# 1/1 [==============================] - 0s 26ms/step
# Normal
# 1/1 [==============================] - 0s 25ms/step
# Abnormal

# %%
model = load_model('files/non-aug/best_yeast_classification_model.hdf5')

# %%
def predict_cell(train_folder,mask_folder,image_path, mask_path, save_folder):
  # for origin_image in os.listdir(origin_image_folder):
    #print(dem1)
    anh_goc = cv2.imread(os.path.join(train_folder,image_path))
    watershed = cv2.imread(os.path.join(mask_folder, mask_path))

    anh_xam = cv2.cvtColor(watershed, cv2.COLOR_BGR2GRAY)
    ret,nguong1 = cv2.threshold(anh_xam, 127, 255, cv2.THRESH_BINARY)
    nguong2 = cv2.bitwise_not(nguong1)
    contours, _ = cv2.findContours(nguong2, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
    MIN_HEIGHT = 4
    MAX_HEIGHT = anh_goc.shape[0] *0.5

    for cnt in contours[:-1]:
      x,y,w,h = cv2.boundingRect(cnt)
      if w > MIN_HEIGHT and w <MAX_HEIGHT:
        crop_number = anh_goc[y-1:y+h+1, x-1:x+w+1]
        crop_number = pad_img(crop_number, (32, 32))
        label = model.predict(np.expand_dims(crop_number, axis=0))
        if(np.argmax(label)) :
          cv2.rectangle(anh_goc, (x, y), (x + w, y + h), (255, 0, 255), 2)
        else:
          cv2.rectangle(anh_goc, (x, y), (x + w, y + h), (0, 255, 0), 2)
        # saved_path = cropped_cells_folder+ '/{}_{}.png'.format(dem1, dem)
        # cv2_imshow(crop_number)
        #cv2.imwrite(saved_path, crop_number)
    cv2_imshow(anh_goc)
    cv2.imwrite(os.path.join(save_folder, "predicted_cell" + image_path), anh_goc)
# print(len(train_anh_goc_list))
# print(len(train_watershed_mask_list))

# %% [markdown]
# ###*Test thử trên ảnh đã gán nhãn*

# %%
test_image_folder = "BackTest/2h"
test_mask_folder = "BackTest/2h_watershed"
test_image_list = sorted(os.listdir(test_image_folder))
test_mask_list = sorted(os.listdir(test_mask_folder))
save_folder = "Predict_Image"
for i in range(len(test_image_list)):
  predict_cell(test_image_folder,test_mask_folder,test_image_list[i], test_mask_list[i],save_folder)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
